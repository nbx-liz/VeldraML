# %% [markdown]
# # Phase26.2 UC-5 Causal DR-DiD estimate
#
# DR-DiD panel estimation walkthrough.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
from veldra.api import fit, tune, evaluate, estimate_dr, export
ROOT = Path('.').resolve()
OUT_DIR = ROOT / 'examples' / 'out' / 'phase26_2_uc05_causal_drdid_estimate'
OUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# {
#   "status": "setup_ok",
#   "out_dir": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc05_causal_drdid_estimate"
# }

# %% [markdown]
# ## Workflow

# %%
result = estimate_dr(config)
result.metadata
# Out:
# {
#   "status": "executed"
# }

# %% [markdown]
# ## Result Summary

# %%
SUMMARY = {
  "uc": "UC-5",
  "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
  "status": "passed",
  "artifact_path": null,
  "outputs": [
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc05_causal_drdid_estimate/artifacts/causal/0877e84873d7463e8ec5409b5baa8089/dr_summary.json",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc05_causal_drdid_estimate/artifacts/causal/0877e84873d7463e8ec5409b5baa8089/dr_observation_table.parquet"
  ],
  "method": "dr_did",
  "design": "panel",
  "estimate": 1652.9920093185222,
  "metrics": {
    "naive": 1761.918956706721,
    "ipw": 1752.308513330445,
    "dr": 1652.9920093185222,
    "treated_rate": 0.31666666666666665,
    "coverage_treated": 0.35731863131745134,
    "overlap_metric": 1.0,
    "smd_max_unweighted": 0.6656165686628388,
    "smd_max_weighted": 0.3953275808466241,
    "drdid": 1652.9920093185222
  }
}
SUMMARY
# Out:
# {
#   "uc": "UC-5",
#   "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#   "status": "passed",
#   "artifact_path": null,
#   "outputs": [
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc05_causal_drdid_estimate/artifacts/causal/0877e84873d7463e8ec5409b5baa8089/dr_summary.json",
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc05_causal_drdid_estimate/artifacts/causal/0877e84873d7463e8ec5409b5baa8089/dr_observation_table.parquet"
#   ],
#   "method": "dr_did",
#   "design": "panel",
#   "estimate": 1652.9920093185222,
#   "metrics": {
#     "naive": 1761.918956706721,
#     "ipw": 1752.308513330445,
#     "dr": 1652.9920093185222,
#     "treated_rate": 0.31666666666666665,
#     "coverage_treated": 0.35731863131745134,
#     "overlap_metric": 1.0,
#     "smd_max_unweighted": 0.6656165686628388,
#     "smd_max_weighted": 0.3953275808466241,
#     "drdid": 1652.9920093185222
#   }
# }
