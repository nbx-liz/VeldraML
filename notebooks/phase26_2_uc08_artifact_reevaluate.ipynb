# %% [markdown]
# # Phase26.2 UC-8 Re-evaluate and precheck
#
# Re-evaluation with schema precheck walkthrough.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
from veldra.api import fit, tune, evaluate, estimate_dr, export
ROOT = Path('.').resolve()
OUT_DIR = ROOT / 'examples' / 'out' / 'phase26_2_uc08_artifact_reevaluate'
OUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# {
#   "status": "setup_ok",
#   "out_dir": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc08_artifact_reevaluate"
# }

# %% [markdown]
# ## Workflow

# %%
precheck = _cb_result_eval_precheck(artifact_path, data_path)
eval_result = evaluate(artifact, data_df)
# Out:
# {
#   "status": "executed"
# }

# %% [markdown]
# ## Result Summary

# %%
SUMMARY = {
  "uc": "UC-8",
  "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
  "status": "passed",
  "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a",
  "outputs": [
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc08_artifact_reevaluate/reeval_ok.csv",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc08_artifact_reevaluate/reeval_missing_col.csv"
  ],
  "precheck_ok_contains": false,
  "precheck_bad_contains_missing": true,
  "metrics": {
    "rmse": 0.9830399692399584,
    "mae": 0.6868666389739531,
    "r2": 0.8831589119942004
  }
}
SUMMARY
# Out:
# {
#   "uc": "UC-8",
#   "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#   "status": "passed",
#   "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a",
#   "outputs": [
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc08_artifact_reevaluate/reeval_ok.csv",
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc08_artifact_reevaluate/reeval_missing_col.csv"
#   ],
#   "precheck_ok_contains": false,
#   "precheck_bad_contains_missing": true,
#   "metrics": {
#     "rmse": 0.9830399692399584,
#     "mae": 0.6868666389739531,
#     "r2": 0.8831589119942004
#   }
# }
