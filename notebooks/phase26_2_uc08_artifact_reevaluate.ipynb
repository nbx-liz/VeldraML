# %% [markdown]
# # Legacy Notebook (Compatibility Stub)\nMoved to `notebooks/quick_reference/reference_08_artifact_reevaluate.ipynb`.\n\nThis legacy path remains for one release and will be removed in the next release cycle.
