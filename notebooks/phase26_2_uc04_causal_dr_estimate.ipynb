# %% [markdown]
# # Phase26.2 UC-4 Causal DR estimate
#
# Doubly robust causal estimate walkthrough.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
from veldra.api import fit, tune, evaluate, estimate_dr, export
ROOT = Path('.').resolve()
OUT_DIR = ROOT / 'examples' / 'out' / 'phase26_2_uc04_causal_dr_estimate'
OUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# {
#   "status": "setup_ok",
#   "out_dir": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc04_causal_dr_estimate"
# }

# %% [markdown]
# ## Workflow

# %%
result = estimate_dr(config)
result.metrics
# Out:
# {
#   "status": "executed"
# }

# %% [markdown]
# ## Result Summary

# %%
SUMMARY = {
  "uc": "UC-4",
  "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
  "status": "passed",
  "artifact_path": null,
  "outputs": [
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc04_causal_dr_estimate/artifacts/causal/bb0bc2be03d44366bbb938e56bba9668/dr_summary.json",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc04_causal_dr_estimate/artifacts/causal/bb0bc2be03d44366bbb938e56bba9668/dr_observation_table.parquet"
  ],
  "method": "dr",
  "estimand": "att",
  "estimate": 1.6922779321622592,
  "metrics": {
    "naive": 2.1673687507712733,
    "ipw": 2.0883447703157816,
    "dr": 1.6922779321622592,
    "treated_rate": 0.4722222222222222,
    "coverage_treated": 0.47807947926359146,
    "overlap_metric": 1.0,
    "smd_max_unweighted": 0.4679346916539189,
    "smd_max_weighted": 0.3933890656954471
  }
}
SUMMARY
# Out:
# {
#   "uc": "UC-4",
#   "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#   "status": "passed",
#   "artifact_path": null,
#   "outputs": [
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc04_causal_dr_estimate/artifacts/causal/bb0bc2be03d44366bbb938e56bba9668/dr_summary.json",
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc04_causal_dr_estimate/artifacts/causal/bb0bc2be03d44366bbb938e56bba9668/dr_observation_table.parquet"
#   ],
#   "method": "dr",
#   "estimand": "att",
#   "estimate": 1.6922779321622592,
#   "metrics": {
#     "naive": 2.1673687507712733,
#     "ipw": 2.0883447703157816,
#     "dr": 1.6922779321622592,
#     "treated_rate": 0.4722222222222222,
#     "coverage_treated": 0.47807947926359146,
#     "overlap_metric": 1.0,
#     "smd_max_unweighted": 0.4679346916539189,
#     "smd_max_weighted": 0.3933890656954471
#   }
# }
