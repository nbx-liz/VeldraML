# %% [markdown]
# # Phase26.2 UC-6 Causal DR tune
#
# Causal objective tuning walkthrough.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
from veldra.api import fit, tune, evaluate, estimate_dr, export
ROOT = Path('.').resolve()
OUT_DIR = ROOT / 'examples' / 'out' / 'phase26_2_uc06_causal_dr_tune'
OUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# {
#   "status": "setup_ok",
#   "out_dir": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc06_causal_dr_tune"
# }

# %% [markdown]
# ## Workflow

# %%
tune_result = tune(config)
tune_result.metadata
# Out:
# {
#   "status": "executed"
# }

# %% [markdown]
# ## Result Summary

# %%
SUMMARY = {
  "uc": "UC-6",
  "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
  "status": "passed",
  "artifact_path": null,
  "outputs": [
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc06_causal_dr_tune/artifacts/tuning/phase26_2_uc06_20260217021219/trials.parquet",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc06_causal_dr_tune/artifacts/tuning/phase26_2_uc06_20260217021219/study_summary.json"
  ],
  "metric_name": "dr_balance_priority",
  "best_score": 1000000.1278141164
}
SUMMARY
# Out:
# {
#   "uc": "UC-6",
#   "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#   "status": "passed",
#   "artifact_path": null,
#   "outputs": [
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc06_causal_dr_tune/artifacts/tuning/phase26_2_uc06_20260217021219/trials.parquet",
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc06_causal_dr_tune/artifacts/tuning/phase26_2_uc06_20260217021219/study_summary.json"
#   ],
#   "metric_name": "dr_balance_priority",
#   "best_score": 1000000.1278141164
# }
