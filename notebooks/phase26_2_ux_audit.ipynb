# %% [markdown]
# # Phase26.2 UX Audit Hub
#
# This hub links executed UC notebooks and captures final A-D gap decisions.

# %% [markdown]
# ## UC Notebook Index
#
# - UC-1: `phase26_2_uc01_regression_fit_evaluate.ipynb`
# - UC-2: `phase26_2_uc02_binary_tune_evaluate.ipynb`
# - UC-3: `phase26_2_uc03_frontier_fit_evaluate.ipynb`
# - UC-4: `phase26_2_uc04_causal_dr_estimate.ipynb`
# - UC-5: `phase26_2_uc05_causal_drdid_estimate.ipynb`
# - UC-6: `phase26_2_uc06_causal_dr_tune.ipynb`
# - UC-7: `phase26_2_uc07_artifact_evaluate.ipynb`
# - UC-8: `phase26_2_uc08_artifact_reevaluate.ipynb`
# - UC-9: `phase26_2_uc09_export_python_onnx.ipynb`
# - UC-10: `phase26_2_uc10_export_html_excel.ipynb`

# %% [markdown]
# ## Gap Classification (A-D)
#
# - A: helper text gaps
# - B: dynamic guidance gaps
# - C: recommendation/preset rationale gaps
# - D: navigation/shortcut gaps

# %%
import json
from pathlib import Path
manifest_path = Path('notebooks/phase26_2_execution_manifest.json')
manifest = json.loads(manifest_path.read_text(encoding='utf-8'))
manifest['entries']
# Out:
# [
#   {
#     "uc": "UC-1",
#     "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#     "status": "passed",
#     "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a",
#     "outputs": [
#       "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/train.csv",
#       "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/test.csv",
#       "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a"
#     ],
#     "metrics": {
#       "rmse": 1.282374188733655,
#       "mae": 0.825028994527357,
#       "r2": 0.802467026319801
#     }
#   },
#   {
#     "uc": "UC-2",
#     "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#     "status": "passed",
# ...

# %% [markdown]
# ## Priority Finalization
#
# - P0: Causal required-input guidance + Run guardrails
# - P1: Validation split recommendations + objective explanations
# - P2: Runs/Results shortcut clarity
#
# Final evidence source: `notebooks/phase26_2_execution_manifest.json` and GUI parity report.
