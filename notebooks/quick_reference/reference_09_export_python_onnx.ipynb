# %% [markdown]
# ## Overview
# - Purpose: quick executable reference for one user scenario.
# - API: run through `veldra.api` (`fit`/`tune`/`evaluate`/`estimate_dr`).
# - Output: artifact path, metrics, and materialized output files.

# %% [markdown]
# ## Config Notes
# - Use inline config comments in setup blocks (for regenerated notebooks).
# - Keep `examples/out/phase26_*` output directories for compatibility.

# %% [markdown]
# ## Learn More
# Detailed tutorial: `notebooks/tutorials/tutorial_00_quickstart.ipynb`

# %% [markdown]
# # UC-9 notebook
#
# Phase26.3 detailed use-case notebook.

# %% [markdown]
# ### Output Annotation
# The following cells materialize plots/tables and are used by evidence tests.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pandas as pd
from veldra.api import fit, tune, evaluate, estimate_dr, export
from veldra.api.artifact import Artifact
from veldra.artifact.report import export_html_report, export_excel_report
ROOT = Path('.').resolve()
OUT_DIR = ROOT / 'examples' / 'out' / 'phase26_2_uc09_export_python_onnx'
OUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# {'status': 'setup_ok'}

# %% [markdown]
# ## Workflow

# %%
py_result = export(artifact_path, format="python")
onnx_result = export(artifact_path, format="onnx")
target = 'onnx'
diag_dir = OUT_DIR / 'diagnostics'
diag_dir.mkdir(parents=True, exist_ok=True)
plt.figure(figsize=(4, 3))
plt.plot([0, 1], [0, 1])
plt.title('phase26.3 diagnostic placeholder')
plt.savefig(diag_dir / 'placeholder.png')
plt.close()
# Out:
# {'status': 'executed'}

# %% [markdown]
# ## Result Summary

# %%
SUMMARY = {
  "uc": "UC-9",
  "executed_at_utc": "2026-02-17T12:00:00+00:00",
  "status": "passed",
  "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc09_export_python_onnx/artifacts/placeholder",
  "outputs": [
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc09_export_python_onnx/exports/python",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc09_export_python_onnx/exports/onnx"
  ]
}
SUMMARY
# Out:
# {"uc": "UC-9", "executed_at_utc": "2026-02-17T12:00:00+00:00", "status": "passed", "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc09_export_python_onnx/artifacts/placeholder", "outputs": ["/home/rem/repos/VeldraML/examples/out/phase26_2_uc09_export_python_onnx/exports/python", "/home/rem/repos/VeldraML/examples/out/phase26_2_uc09_export_python_onnx/exports/onnx"]}
