# %% [markdown]
# # Tutorial 00: Quickstart

# %% [markdown]
# ## Concept Primer
# Run the smallest end-to-end flow in ~10 minutes.

# %% [markdown]
# ## Config Guide
# Use regression defaults first, then adjust splits and metrics.

# %% [markdown]
# ## Result Interpretation
# Check RMSE/MAE together and inspect prediction residuals.

# %% [markdown]
# ## If-Then Sensitivity
# If RMSE unstable across folds, increase `n_splits` and regularization.

# %% [markdown]
# ## Common Pitfalls
# Do not include target leakage columns in features.

# %% [markdown]
# ## Further Reading
# - tutorials/tutorial_01_regression_basics.ipynb
# - README notebook section
