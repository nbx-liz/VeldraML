# %% [markdown]
# # Tutorial 07: Model Evaluation Guide

# %% [markdown]
# ## Concept Primer
# Choose metrics by business loss shape and class balance.

# %% [markdown]
# ## Config Guide
# Map `task.type` to compatible `train.metrics` and `tuning.objective`.

# %% [markdown]
# ## Result Interpretation
# Use calibration/coverage checks before deployment thresholds.

# %% [markdown]
# ## If-Then Sensitivity
# Compare metric movement under threshold and split strategy changes.

# %% [markdown]
# ## Common Pitfalls
# Avoid optimizing one metric while monitoring an incompatible one.

# %% [markdown]
# ## Further Reading
# - diagnostics notebooks in quick_reference/
# - DESIGN_BLUEPRINT 13.4
