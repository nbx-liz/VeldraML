# %% [markdown]
# # Phase26.2 UC-1 Regression fit/evaluate
#
# Regression training and evaluation walkthrough.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
from veldra.api import fit, tune, evaluate, estimate_dr, export
ROOT = Path('.').resolve()
OUT_DIR = ROOT / 'examples' / 'out' / 'phase26_2_uc01_regression_fit_evaluate'
OUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# {
#   "status": "setup_ok",
#   "out_dir": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate"
# }

# %% [markdown]
# ## Workflow

# %%
run_result = fit(config)
artifact = Artifact.load(run_result.artifact_path)
eval_result = evaluate(artifact, test_df)
# Out:
# {
#   "status": "executed"
# }

# %% [markdown]
# ## Result Summary

# %%
SUMMARY = {
  "uc": "UC-1",
  "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
  "status": "passed",
  "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a",
  "outputs": [
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/train.csv",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/test.csv",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a"
  ],
  "metrics": {
    "rmse": 1.282374188733655,
    "mae": 0.825028994527357,
    "r2": 0.802467026319801
  }
}
SUMMARY
# Out:
# {
#   "uc": "UC-1",
#   "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#   "status": "passed",
#   "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a",
#   "outputs": [
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/train.csv",
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/test.csv",
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc01_regression_fit_evaluate/artifacts/fb6d5a425ebc45ec9bb47a6d2811b18a"
#   ],
#   "metrics": {
#     "rmse": 1.282374188733655,
#     "mae": 0.825028994527357,
#     "r2": 0.802467026319801
#   }
# }
