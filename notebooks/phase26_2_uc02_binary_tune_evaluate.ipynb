# %% [markdown]
# # Phase26.2 UC-2 Binary tune/evaluate
#
# Binary tuning plus post-fit evaluation walkthrough.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
from veldra.api import fit, tune, evaluate, estimate_dr, export
ROOT = Path('.').resolve()
OUT_DIR = ROOT / 'examples' / 'out' / 'phase26_2_uc02_binary_tune_evaluate'
OUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# {
#   "status": "setup_ok",
#   "out_dir": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc02_binary_tune_evaluate"
# }

# %% [markdown]
# ## Workflow

# %%
tune_result = tune(config)
run_result = fit(fit_config)
eval_result = evaluate(Artifact.load(run_result.artifact_path), test_df)
# Out:
# {
#   "status": "executed"
# }

# %% [markdown]
# ## Result Summary

# %%
SUMMARY = {
  "uc": "UC-2",
  "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
  "status": "passed",
  "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc02_binary_tune_evaluate/artifacts_fit/545a96ef99da4b599f438d955d051cc3",
  "outputs": [
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc02_binary_tune_evaluate/artifacts/tuning/phase26_2_uc02_20260217021219/trials.parquet",
    "/home/rem/repos/VeldraML/examples/out/phase26_2_uc02_binary_tune_evaluate/artifacts_fit/545a96ef99da4b599f438d955d051cc3"
  ],
  "tune_metric_name": "auc",
  "best_score": 0.9337484035759898,
  "eval_metrics": {
    "auc": 0.9895833333333334,
    "logloss": 0.19767602168665682,
    "brier": 0.04137895968194719,
    "accuracy": 0.9642857142857143,
    "f1": 0.9565217391304348,
    "precision": 1.0,
    "recall": 0.9166666666666666,
    "threshold": 0.43
  }
}
SUMMARY
# Out:
# {
#   "uc": "UC-2",
#   "executed_at_utc": "2026-02-17T02:12:19.733939+00:00",
#   "status": "passed",
#   "artifact_path": "/home/rem/repos/VeldraML/examples/out/phase26_2_uc02_binary_tune_evaluate/artifacts_fit/545a96ef99da4b599f438d955d051cc3",
#   "outputs": [
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc02_binary_tune_evaluate/artifacts/tuning/phase26_2_uc02_20260217021219/trials.parquet",
#     "/home/rem/repos/VeldraML/examples/out/phase26_2_uc02_binary_tune_evaluate/artifacts_fit/545a96ef99da4b599f438d955d051cc3"
#   ],
#   "tune_metric_name": "auc",
#   "best_score": 0.9337484035759898,
#   "eval_metrics": {
#     "auc": 0.9895833333333334,
#     "logloss": 0.19767602168665682,
#     "brier": 0.04137895968194719,
#     "accuracy": 0.9642857142857143,
#     "f1": 0.9565217391304348,
#     "precision": 1.0,
#     "recall": 0.9166666666666666,
#     "threshold": 0.43
#   }
# }
